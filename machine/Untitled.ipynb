# %%
# %matplotlib inline
import pyfolio as pf

# %%
stock_rets = pf.utils.get_symbol_rets('VTI')

# %%
pf.create_returns_tear_sheet(stock_rets, live_start_date='2007-01-01')
# Out:
# Entire data start date: 2001-06-18 00:00:00+00:00
# Entire data end date: 2015-08-21 00:00:00+00:00
#
#
# Out-of-Sample Months: 103
# Backtest Months: 66
#                    Backtest  Out_of_Sample  All_History
# annual_return          0.07           0.09         0.08
# annual_volatility      0.16           0.22         0.20
# sharpe_ratio           0.44           0.40         0.41
# calmar_ratio           0.21           0.16         0.15
# stability              0.67           0.61         0.73
# max_drawdown          -0.35          -0.55        -0.55
# omega_ratio            1.08           1.08         1.08
# sortino_ratio          0.67           0.52         0.55
# skewness               0.21           0.01         0.05
# kurtosis               2.86           9.93         9.50
# alpha                  0.02           0.01         0.01
# beta                   0.96           0.99         0.98
#
# Worst Drawdown Periods
# ...
